# %%
import re
import os
import asyncio 
from io import BytesIO
from typing import IO, List, Optional
from dotenv import load_dotenv
from langchain_community.graphs import Neo4jGraph
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings
from langchain.chains import GraphCypherQAChain
from langchain_unstructured import UnstructuredLoader
from langchain_community.vectorstores import Neo4jVector
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_experimental.graph_transformers import LLMGraphTransformer
from pydantic import BaseModel, Field
from graphdatascience import GraphDataScience
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.messages import SystemMessage
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm
import logging

load_dotenv()

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

class DuplicateEntities(BaseModel):
    entities: List[str] = Field(
        description="Entities that represent the same object or real-world entity and should be merged"
    )

class Disambiguate(BaseModel):
    merge_entities: Optional[List[DuplicateEntities]] = Field(
        description="Lists of entities that represent the same object or real-world entity and should be merged"
    )

class OptimizeGraph:
    def __init__(self):
        self.graph_chain = None
        self.store = None
        self.graph = None
        self.merged_entities = []

    def init_graph(self):
        self.graph = Neo4jGraph(
            url=os.environ["NEO4J_URI"],
            username=os.environ["NEO4J_USERNAME"],
            password=os.environ["NEO4J_PASSWORD"],
        )

    def init_vector(self):
        index_name = "vector"
        store = Neo4jVector.from_existing_index(
            OpenAIEmbeddings(),
            url=os.environ["NEO4J_URI"],
            username=os.environ["NEO4J_USERNAME"],
            password=os.environ["NEO4J_PASSWORD"],
            index_name=index_name,
        )
        self.store = store

    def add_embeddings_to_nodes(self):
        vector = Neo4jVector.from_existing_graph(
            OpenAIEmbeddings(),
            node_label='__Entity__',
            text_node_properties=['id', 'description'],
            embedding_node_property='embedding',
        )

    def add_relationships_similar(self):
        gds = GraphDataScience(
            os.environ["NEO4J_URI"],
            auth=(os.environ["NEO4J_USERNAME"], os.environ["NEO4J_PASSWORD"]),
        )
        G, result = gds.graph.project(
            "entities",                   # Graph name
            "__Entity__",                 # Node projection
            "*",                          # Relationship projection
            nodeProperties=["embedding"]  # Configuration parameters
        )
        similarity_threshold = 0.95

        gds.knn.mutate(
            G,
            nodeProperties=['embedding'],
            mutateRelationshipType='SIMILAR',
            mutateProperty='score',
            similarityCutoff=similarity_threshold
        )

        gds.wcc.write(
            G,
            writeProperty="wcc",
            relationshipTypes=["SIMILAR"]
        )

    def get_potential_duplicate_candidates(self):
        self.init_graph()
        word_edit_distance = 3
        potential_duplicate_candidates = self.graph.query(
            """MATCH (e:`__Entity__`)
            WHERE size(e.id) > 3 // longer than 3 characters
            WITH e.wcc AS community, collect(e) AS nodes, count(*) AS count
            WHERE count > 1
            UNWIND nodes AS node
            // Add text distance
            WITH distinct
            [n IN nodes WHERE apoc.text.distance(toLower(node.id), toLower(n.id)) < $distance 
                        OR node.id CONTAINS n.id | n.id] AS intermediate_results
            WHERE size(intermediate_results) > 1
            WITH collect(intermediate_results) AS results
            // combine groups together if they share elements
            UNWIND range(0, size(results)-1, 1) as index
            WITH results, index, results[index] as result
            WITH apoc.coll.sort(reduce(acc = result, index2 IN range(0, size(results)-1, 1) |
                    CASE WHEN index <> index2 AND
                        size(apoc.coll.intersection(acc, results[index2])) > 0
                        THEN apoc.coll.union(acc, results[index2])
                        ELSE acc
                    END
            )) as combinedResult
            WITH distinct(combinedResult) as combinedResult
            // extra filtering
            WITH collect(combinedResult) as allCombinedResults
            UNWIND range(0, size(allCombinedResults)-1, 1) as combinedResultIndex
            WITH allCombinedResults[combinedResultIndex] as combinedResult, combinedResultIndex, allCombinedResults
            WHERE NOT any(x IN range(0,size(allCombinedResults)-1,1)
                WHERE x <> combinedResultIndex
                AND apoc.coll.containsAll(allCombinedResults[x], combinedResult)
            )
            RETURN combinedResult
            """, params={'distance': word_edit_distance}
        )
        return potential_duplicate_candidates or []

    def LLM_finnal_decision_to_merge(self):
        self.init_graph()
        system_prompt = """You are a data processing assistant. Your task is to identify duplicate entities in a list and decide which of them should be merged.
The entities might be slightly different in format or content, but essentially refer to the same thing. Use your analytical skills to determine duplicates.

Here are the rules for identifying duplicates:
1. Entities with minor typographical differences should be considered duplicates.
2. Entities with different formats but the same content should be considered duplicates.
3. Entities that refer to the same real-world object or concept, even if described differently, should be considered duplicates.
4. If it refers to different numbers, dates, or products, do not merge results
"""
        user_template = """
Here is the list of entities to process:
{entities}

Please identify duplicates, merge them, and provide the merged list.
"""
        extraction_llm = ChatOpenAI(model_name="gpt-4o-mini").with_structured_output(
            Disambiguate
        )
        extraction_prompt = ChatPromptTemplate([
            SystemMessage(content=system_prompt),
            ("human", user_template)
        ])
        extraction_chain = extraction_prompt | extraction_llm

        def entity_resolution(entities: List[str]) -> Optional[List[List[str]]]:
            result = extraction_chain.invoke({"entities": entities})
            if result and result.merge_entities:
                return [el.entities for el in result.merge_entities]
            else:
                logger.warning("Entity resolution returned None or unexpected structure.")
                return []

        MAX_WORKERS = 10
        self.merged_entities = []
        potential_duplicate_candidates = self.get_potential_duplicate_candidates()
        with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
            futures = [
                executor.submit(entity_resolution, el.get('combinedResult', []))
                for el in potential_duplicate_candidates
            ]

            for future in tqdm(
                as_completed(futures), total=len(futures), desc="Processing documents"
            ):
                try:
                    to_merge = future.result() or []
                    if to_merge:
                        self.merged_entities.extend(to_merge)
                except Exception as e:
                    logger.error(f"Error processing future: {e}")

        if self.merged_entities:
            # Validate merged entities
            valid_entities = []
            for group in self.merged_entities:
                # Verify that all nodes exist
                result = self.graph.query("""
                    MATCH (e:__Entity__)
                    WHERE e.id IN $ids
                    RETURN count(e) as count
                """, params={'ids': group})
                if result[0]['count'] == len(group):
                    valid_entities.append(group)
                else:
                    logger.warning(f"Skipping merge for group {group} due to missing nodes.")
            # Proceed with valid groups
            for group in valid_entities:
                try:
                    self.graph.query("""
                        MATCH (e:__Entity__)
                        WHERE e.id IN $candidates
                        WITH collect(e) AS nodes
                        CALL apoc.refactor.mergeNodes(nodes, {properties: {
                            description:'combine',
                            `.*`: 'discard'
                        }})
                        YIELD node
                        RETURN node
                    """, params={"candidates": group})
                except Exception as e:
                    logger.error(f"Failed to merge nodes {group}: {e}")
        else:
            logger.info("No entities to merge.")

    def optimize_graph(self):
        self.init_graph()
        self.add_embeddings_to_nodes()
        self.add_relationships_similar()
        self.LLM_finnal_decision_to_merge()

# %%
print(os.environ["NEO4J_URI"])
print(os.environ["NEO4J_USERNAME"])
print(os.environ["NEO4J_PASSWORD"])
# Out:
# neo4j+s://4ee31ee1.databases.neo4j.io
# neo4j
# WDPZl8DBi-2uDnlUAyLaWFluM-ViC3FdY5LgxUcH1u0

# %%
optimize = OptimizeGraph()

# %%
# optimize.optimize_graph()

# %%
optimize.LLM_finnal_decision_to_merge()
# Out:
# Processing documents:   0%|          | 0/217 [00:00<?, ?it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# WARNING:__main__:Entity resolution returned None or unexpected structure.
# Processing documents:   0%|          | 1/217 [00:00<02:45,  1.31it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:   1%|          | 2/217 [00:00<01:22,  2.60it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:   2%|▏         | 5/217 [00:01<00:29,  7.09it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# WARNING:__main__:Entity resolution returned None or unexpected structure.
# Processing documents:   4%|▎         | 8/217 [00:01<00:26,  7.93it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:   5%|▍         | 10/217 [00:01<00:25,  8.13it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# WARNING:__main__:Entity resolution returned None or unexpected structure.
# Processing documents:   6%|▋         | 14/217 [00:01<00:16, 12.64it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:   7%|▋         | 16/217 [00:01<00:14, 13.51it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:   8%|▊         | 18/217 [00:02<00:24,  8.08it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:   9%|▉         | 20/217 [00:02<00:31,  6.25it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  10%|█         | 22/217 [00:03<00:30,  6.35it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  11%|█         | 24/217 [00:03<00:40,  4.78it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  13%|█▎        | 28/217 [00:04<00:25,  7.31it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  14%|█▍        | 30/217 [00:05<00:46,  4.03it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  14%|█▍        | 31/217 [00:06<01:07,  2.77it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  15%|█▍        | 32/217 [00:13<05:03,  1.64s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  15%|█▌        | 33/217 [00:14<04:29,  1.46s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  16%|█▌        | 34/217 [00:16<04:23,  1.44s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  16%|█▌        | 35/217 [00:16<03:35,  1.18s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  17%|█▋        | 36/217 [00:17<03:20,  1.11s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  17%|█▋        | 37/217 [00:18<03:04,  1.02s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  18%|█▊        | 38/217 [00:18<02:45,  1.08it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  18%|█▊        | 39/217 [00:20<03:40,  1.24s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  18%|█▊        | 40/217 [00:21<03:10,  1.07s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  19%|█▉        | 41/217 [00:22<02:52,  1.02it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  19%|█▉        | 42/217 [00:23<02:44,  1.07it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  20%|█▉        | 43/217 [00:24<02:47,  1.04it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  20%|██        | 44/217 [00:24<02:14,  1.28it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  21%|██        | 45/217 [00:25<02:21,  1.22it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  21%|██        | 46/217 [00:26<02:14,  1.27it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  22%|██▏       | 47/217 [00:26<02:07,  1.33it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  22%|██▏       | 48/217 [00:27<01:50,  1.52it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  23%|██▎       | 49/217 [00:30<04:24,  1.58s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  23%|██▎       | 50/217 [00:31<03:29,  1.26s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  24%|██▎       | 51/217 [00:32<03:04,  1.11s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  24%|██▍       | 52/217 [00:32<02:47,  1.02s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  24%|██▍       | 53/217 [00:33<02:44,  1.00s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  25%|██▍       | 54/217 [00:35<03:10,  1.17s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  25%|██▌       | 55/217 [00:35<02:31,  1.07it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  26%|██▌       | 56/217 [00:36<02:23,  1.12it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  26%|██▋       | 57/217 [00:37<02:08,  1.24it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  27%|██▋       | 58/217 [00:37<02:05,  1.26it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  28%|██▊       | 60/217 [00:38<01:36,  1.63it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  29%|██▊       | 62/217 [00:39<01:18,  1.97it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  29%|██▉       | 63/217 [00:39<01:06,  2.30it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  29%|██▉       | 64/217 [00:40<01:15,  2.03it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  30%|██▉       | 65/217 [00:41<01:26,  1.75it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  30%|███       | 66/217 [00:41<01:31,  1.65it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  31%|███       | 67/217 [00:42<01:25,  1.76it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  31%|███▏      | 68/217 [00:45<03:02,  1.23s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  32%|███▏      | 69/217 [00:46<02:44,  1.11s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  32%|███▏      | 70/217 [00:47<02:54,  1.18s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  33%|███▎      | 71/217 [00:47<02:24,  1.01it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  33%|███▎      | 72/217 [00:48<02:17,  1.05it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  34%|███▎      | 73/217 [00:49<02:16,  1.06it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  34%|███▍      | 74/217 [00:52<03:21,  1.41s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  35%|███▍      | 75/217 [00:53<02:58,  1.25s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  35%|███▌      | 77/217 [00:53<02:01,  1.15it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  36%|███▋      | 79/217 [00:54<01:30,  1.52it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  37%|███▋      | 80/217 [00:58<02:59,  1.31s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  37%|███▋      | 81/217 [00:58<02:34,  1.14s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  38%|███▊      | 82/217 [00:59<02:05,  1.07it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  38%|███▊      | 83/217 [01:00<02:03,  1.08it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  39%|███▊      | 84/217 [01:13<09:42,  4.38s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  39%|███▉      | 85/217 [01:17<09:14,  4.20s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  40%|███▉      | 86/217 [01:20<08:28,  3.89s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  40%|████      | 87/217 [01:21<06:43,  3.10s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  41%|████      | 88/217 [01:22<05:14,  2.43s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  41%|████      | 89/217 [01:23<04:31,  2.12s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  41%|████▏     | 90/217 [01:24<03:45,  1.77s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  42%|████▏     | 91/217 [01:29<05:38,  2.69s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  42%|████▏     | 92/217 [01:31<04:53,  2.35s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  43%|████▎     | 93/217 [01:31<03:35,  1.74s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  43%|████▎     | 94/217 [01:31<02:38,  1.29s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  44%|████▍     | 95/217 [01:32<02:05,  1.03s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  45%|████▍     | 97/217 [01:32<01:09,  1.71it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  45%|████▌     | 98/217 [01:32<01:02,  1.91it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  46%|████▌     | 99/217 [01:32<00:54,  2.16it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  46%|████▌     | 100/217 [01:32<00:44,  2.62it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  47%|████▋     | 102/217 [01:33<00:36,  3.12it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  48%|████▊     | 104/217 [01:33<00:33,  3.37it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  48%|████▊     | 105/217 [01:34<00:32,  3.42it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  49%|████▉     | 106/217 [01:34<00:31,  3.48it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  49%|████▉     | 107/217 [01:35<00:36,  2.98it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  50%|█████     | 109/217 [01:35<00:28,  3.76it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  51%|█████     | 110/217 [01:35<00:31,  3.43it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  52%|█████▏    | 112/217 [01:36<00:37,  2.81it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  52%|█████▏    | 113/217 [01:37<00:49,  2.11it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  53%|█████▎    | 114/217 [01:39<01:19,  1.29it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  53%|█████▎    | 115/217 [01:40<01:20,  1.26it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  53%|█████▎    | 116/217 [01:40<01:18,  1.29it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  54%|█████▍    | 117/217 [01:41<01:15,  1.33it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  54%|█████▍    | 118/217 [01:42<01:18,  1.26it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  55%|█████▍    | 119/217 [01:43<01:14,  1.32it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  55%|█████▌    | 120/217 [01:43<01:15,  1.29it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  56%|█████▌    | 121/217 [01:44<01:21,  1.18it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  56%|█████▌    | 122/217 [01:45<01:19,  1.20it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# WARNING:__main__:Entity resolution returned None or unexpected structure.
# Processing documents:  57%|█████▋    | 123/217 [01:46<01:10,  1.34it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  57%|█████▋    | 124/217 [01:47<01:28,  1.05it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  58%|█████▊    | 126/217 [01:48<01:02,  1.46it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  59%|█████▉    | 128/217 [01:49<00:53,  1.68it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  60%|█████▉    | 130/217 [01:49<00:37,  2.30it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  60%|██████    | 131/217 [01:50<00:39,  2.20it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  61%|██████    | 132/217 [01:50<00:33,  2.55it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  61%|██████▏   | 133/217 [01:51<00:38,  2.21it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  62%|██████▏   | 135/217 [01:51<00:35,  2.34it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  63%|██████▎   | 136/217 [01:52<00:45,  1.78it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  63%|██████▎   | 137/217 [01:57<01:56,  1.45s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  64%|██████▎   | 138/217 [02:06<04:44,  3.60s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  64%|██████▍   | 139/217 [02:09<04:17,  3.30s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  65%|██████▍   | 140/217 [02:15<05:10,  4.04s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  65%|██████▍   | 141/217 [02:17<04:38,  3.66s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  65%|██████▌   | 142/217 [02:19<03:58,  3.18s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  66%|██████▌   | 143/217 [02:20<03:04,  2.49s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  66%|██████▋   | 144/217 [02:21<02:21,  1.94s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  67%|██████▋   | 145/217 [02:22<02:05,  1.74s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  67%|██████▋   | 146/217 [02:24<01:56,  1.65s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  68%|██████▊   | 147/217 [02:25<01:44,  1.49s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  68%|██████▊   | 148/217 [02:25<01:19,  1.15s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  69%|██████▊   | 149/217 [02:27<01:39,  1.47s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  69%|██████▉   | 150/217 [02:27<01:13,  1.09s/it]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  70%|██████▉   | 151/217 [02:28<00:54,  1.20it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  70%|███████   | 152/217 [02:28<00:46,  1.40it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  71%|███████   | 153/217 [02:28<00:37,  1.71it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  71%|███████   | 154/217 [02:29<00:37,  1.68it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  71%|███████▏  | 155/217 [02:29<00:27,  2.23it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  72%|███████▏  | 156/217 [02:29<00:21,  2.78it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  72%|███████▏  | 157/217 [02:30<00:25,  2.33it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  73%|███████▎  | 159/217 [02:31<00:23,  2.46it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  74%|███████▎  | 160/217 [02:31<00:20,  2.79it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  74%|███████▍  | 161/217 [02:31<00:22,  2.48it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  75%|███████▍  | 162/217 [02:32<00:24,  2.26it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  75%|███████▌  | 163/217 [02:32<00:20,  2.68it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  76%|███████▌  | 164/217 [02:33<00:22,  2.40it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  76%|███████▌  | 165/217 [02:33<00:20,  2.48it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  76%|███████▋  | 166/217 [02:34<00:24,  2.08it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  77%|███████▋  | 167/217 [02:35<00:30,  1.66it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  77%|███████▋  | 168/217 [02:35<00:28,  1.70it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  78%|███████▊  | 170/217 [02:36<00:22,  2.05it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  79%|███████▉  | 172/217 [02:36<00:14,  3.18it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  80%|███████▉  | 173/217 [02:37<00:17,  2.54it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  80%|████████  | 174/217 [02:37<00:14,  2.90it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  81%|████████  | 176/217 [02:37<00:12,  3.34it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  82%|████████▏ | 178/217 [02:37<00:08,  4.35it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  82%|████████▏ | 179/217 [02:38<00:10,  3.74it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  83%|████████▎ | 180/217 [02:38<00:08,  4.31it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  83%|████████▎ | 181/217 [02:38<00:07,  4.86it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  84%|████████▍ | 182/217 [02:39<00:09,  3.78it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  85%|████████▍ | 184/217 [02:39<00:06,  5.43it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  85%|████████▌ | 185/217 [02:39<00:05,  5.42it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  86%|████████▌ | 186/217 [02:40<00:10,  2.91it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  88%|████████▊ | 191/217 [02:40<00:05,  4.94it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# WARNING:__main__:Entity resolution returned None or unexpected structure.
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  89%|████████▉ | 194/217 [02:40<00:03,  6.88it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  90%|█████████ | 196/217 [02:41<00:03,  6.90it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  91%|█████████ | 198/217 [02:41<00:03,  6.27it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  93%|█████████▎| 201/217 [02:41<00:02,  7.17it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  94%|█████████▎| 203/217 [02:42<00:01,  7.17it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  94%|█████████▍| 205/217 [02:42<00:01,  8.55it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  95%|█████████▌| 207/217 [02:42<00:01,  7.88it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  96%|█████████▌| 208/217 [02:42<00:01,  8.16it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  97%|█████████▋| 210/217 [02:42<00:00,  9.40it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  98%|█████████▊| 212/217 [02:43<00:00, 10.35it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  99%|█████████▊| 214/217 [02:44<00:00,  3.88it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents:  99%|█████████▉| 215/217 [02:45<00:00,  2.83it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents: 100%|█████████▉| 216/217 [02:47<00:00,  1.39it/s]INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing documents: 100%|██████████| 217/217 [02:50<00:00,  1.27it/s]
# ERROR:neo4j.io:[#E98E]  _: <CONNECTION> error: Failed to read from defunct connection ResolvedIPv4Address(('34.142.144.246', 7687)) (ResolvedIPv4Address(('34.142.144.246', 7687))): OSError('No data')
# ERROR:neo4j.pool:Unable to retrieve routing information
# WARNING:neo4j.pool:Transaction failed and will be retried in 0.9848210499695534s (Unable to retrieve routing information)
# WARNING:__main__:Skipping merge for group ['Electric Vehicle', 'Electric Vehicles', 'Electric Vehicles (Bev)'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Dioxide Emissions', 'Carbon Dioxide Emissions Assessment', 'Carbon Dioxide Emissions From Fertilizer And Lime Usage', 'Carbon Dioxide Emissions From Fertilizer And Lime'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Agricultural Activities', 'Agricultural Activities Data'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emission Factor', 'Greenhouse Gas Emission Factors'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Nitrous Oxide Emissions', 'Nitrous Oxide Emissions From Fertilizer Application', 'Nitrous Oxide Emissions From Soil'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Heat Production', 'Heat Energy Production', 'Heat Energy Generation'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Anaerobic Treatment Process', 'Anaerobic Treatment', 'Anaerobic Treatment Process', 'Anaerobic Wastewater Treatment', 'Anaerobic Wastewater Treatment System', 'Anaerobic_Treatment', 'Anaerobic_Treatment_Emissions', 'Anaerobic_Wastewater_Treatment'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Aerobic Treatment Process', 'Anaerobic Treatment Process', 'Anaerobic Treatment', 'Anaerobic Treatment Process'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Amount Of Nitrous Oxide Emissions', 'Amount Of Nitrous Oxide Emissions From Fertilizer Application', 'Amount Of Nitrous Oxide Emissions From Drainage In Baseline Scenario', 'Amount Of Nitrous Oxide Emissions From Soil'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Dioxide', 'Carbon Dioxide (Co2)', 'Carbon Dioxide Emissions', 'Carbon Dioxide Emissions From Urea Fertilization', 'Carbon Dioxide Emissions From Fertilizer', 'Carbon Dioxide Emissions In Baseline Scenario', 'Carbon Dioxide Recovery And Utilization'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emission Reduction', 'Greenhouse Gas Emission Reduction Activities', 'Greenhouse Gas Emission Reductions', 'Greenhouse Gas Emission Reductions From The Project', 'Greenhouse Gas Emission Reductions And Greenhouse Gas Removal'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emissions From The Use Of Fossil Fuels For Fuel Transport', 'Greenhouse Gas Emissions From The Use Of Fossil Fuels', 'Greenhouse Gas Emissions From The Use Of Fossil Fuels In Project Implementation In Year Y', 'Greenhouse Gas Emissions From The Use Of Fossil Fuels Outside The Project Boundary In Year Y', 'Greenhouse Gas Emissions From The Use Of Fossil Fuels Outside The Project Boundary', 'Greenhouse Gas Emissions From The Use Of Fossil Fuels To Transport Organic Waste Outside The Project Boundary'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Management Organization (Public Organization) (Tgo) Thailand', 'Greenhouse Gas Management Organization (Tgo)'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Nitrous Oxide', 'Nitrous Oxide Emission Factor', 'Nitrous Oxide Emissions', 'Nitrous Oxide Emissions From Fertilizer Application', 'Nitrous Oxide Emissions From Soil'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Ghg Emissions', 'Ghg Emissions From Burning Biomass', 'Ghg Emissions From Fossil Fuel Use'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Emissions', 'Emissions Calculation', 'Emissions From Electricity Consumption'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Emission Reduction', 'Emission Reductions', 'Emission Reductions And Greenhouse Gas Removal', 'Emission Reductions Activities'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Total Greenhouse Gas Emissions', 'Total Greenhouse Gas Emissions From Project Implementation', 'Total Greenhouse Gas Emissions From Project Operations'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Fcpj,Y', 'Fcpj,X,Y', 'Fcpj,I,Y', 'Fcpj,Ng,Y', 'Fcpj,X,Y', 'Fcpj_I_Y', 'Fcpj_Y', 'Fcpj, X, Y'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Emissions', 'Emissions Calculation', 'Emissions Data', 'Emissions Forecasting', 'Emissions From Electricity Consumption', 'Emissions From Fossil Fuel Consumption', 'Emissions From The Project'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Dioxide', 'Carbon Dioxide Emissions', 'Carbon Dioxide Emissions From Fertilizer And Lime Usage', 'Carbon Dioxide Emissions From Urea Fertilization'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Baseline Emission Calculation', 'Baseline Emissions Calculation', 'Baseline Emissions Calculation'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emissions From Burning Fossil Fuels', 'Greenhouse Gas Emissions From Burning Fossil Fuels Type I In Year Y', 'Greenhouse Gas Emissions From Burning Fossil Fuels Type I'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Methane Emissions From Biomass Burning', 'Methane Emissions From Biomass Burning In Year T', 'Methane Emissions From Biomass Burning In Project Implementation'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Dioxide Emissions From Fossil Fuels', 'Carbon Dioxide Emissions From Urea'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Emissions From The Use Of Fossil Fuels', 'Emissions From Fossil Fuel Consumption'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Emissions Calculation', 'Emissions Calculation From Baseline'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Dioxide Emissions From Urea Fertilization', 'Carbon Dioxide Emissions From Urea'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Biomass Emissions', 'Biomass Emissions From Biomass Burning'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Electricity Generation From Hydrogen For Internal Usage Or Grid Reselling', 'Electricity Generation From Hydrogen'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emission Model From Rice Cultivation', 'Greenhouse Gas Emission Factors'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Coal Emissions', 'Coal Emission Factor'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Emission Factor From Urea', 'Carbon Emission Factor For Urea'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Dioxide Emissions From Fertilizer And Lime Usage', 'Carbon Dioxide Emissions From Fertilizer Use'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Anaerobic Treatment Process', 'Anaerobic Treatment', 'Anaerobic Treatment Process'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Baseline Emission Calculation', 'Baseline Emission', 'Baseline Emission Calculation'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Baseline Emissions Calculation', 'Baseline Emissions', 'Baseline Emissions Calculation'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Baseline Emissions Calculation', 'Baseline Emissions', 'Baseline Emissions Calculation'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emissions From Fossil Fuel Use', 'Greenhouse Gas Emissions From Fossil Fuel Consumption', 'Greenhouse Gas Emissions From Fossil Fuel Use In Project Implementation', 'Greenhouse Gas Emissions From Fossil Fuel Consumption From Anaerobic Digestion'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emissions From Fossil Fuel Use', 'Greenhouse Gas Emissions From Fossil Fuel Consumption', 'Greenhouse Gas Emissions From Fossil Fuel Usage', 'Greenhouse Gas Emissions From Fossil Fuels'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Stocks In Woody Biomass', 'Carbon Stocks', 'Carbon Stocks In Soil'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Landfill_Biogas', 'Waste Management', 'Waste Management And Treatment'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Emissions Calculation', 'Emissions From Electricity Consumption', 'Emissions From Electricity Use'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Emission Reductions', 'Emission Reduction Activities', 'Emission Reductions And Greenhouse Gas Removal'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Gas Emissions', 'Gas Emissions From Combustion', 'Gas Emissions From Fossil Fuels'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Wastewater Discharge', 'Wastewater Discharge Amount', 'Wastewater'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Nitrous Oxide Emissions From Biomass Burning', 'Nitrous Oxide Emissions From Soil'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Storage Of Trees In Year T', 'Carbon Storage Of Trees In The Baseline Year', 'Carbon Storage Of Trees In The Project'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emissions Calculation From Project Activities', 'Greenhouse Gas Emissions Calculation From Baseline', 'Greenhouse Gas Emissions Calculation From Project'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Energy Efficiency Improvement For Buildings', 'Improvement Of Energy Efficiency In Buildings', 'Improving Energy Efficiency In Buildings'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Vegetation Carbon Sequestration', 'Vegetation Carbon Stocks', 'Vegetation Carbon'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Soil Carbon Sequestration', 'Soil Carbon', 'Soil Carbon Stock'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Power Generation And Chilled Water Supply From Combined Heat And Power', 'Power Plant', 'Power Generation'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Chemical Oxygen Demand Removal Efficiency Of The Project Wastewater Treatment System K In Year Y', 'Chemical Oxygen Demand Removal Efficiency', 'Chemical Oxygen Demand'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Assessment Method 1', 'Assessment Method 2', 'Assessment Method 3'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Research Project', 'Research', 'Research Activity'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Energy Consumption', 'Energy Efficiency', 'Energy Efficiency Improvements'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Waste Management And Treatment', 'Waste Management', 'Waste Treatment'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Biogas Production', 'Biogas Recovery', 'Biogas Upgrading'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Emission Reductions From Project', 'Emission Reductions From Activities', 'Emission Reductions From Operations'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Watering', 'Water Management', 'Water Use'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Energy Consumption Data', 'Energy Consumption Parameter', 'Energy Consumption Report'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Water Management', 'Watering', 'Water Use'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Waste Management And Treatment', 'Waste Treatment', 'Waste Management'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Water Management', 'Watering', 'Water Use'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Chemical Oxygen Demand', 'Chemical Oxygen Demand Removal Efficiency Of The Project Wastewater Treatment System K In Year Y', 'Chemical Oxygen Demand Removal Efficiency'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Water Management In The Growing Season', 'Water Management', 'Water Use'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Baseline Emissions', 'Baseline Emission', 'Baseline Emission Calculation', 'Baseline Emission Calculation', 'Baseline Emissions Calculation', 'Baseline Emissions Of Sludge Treatment Systems', 'Baseline Ghg Emissions'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Anaerobic Treatment Process', 'Anaerobic Treatment', 'Anaerobic Treatment Process', 'Anaerobic Wastewater Treatment', 'Anaerobic Wastewater Treatment System', 'Anaerobic_Treatment', 'Anaerobic_Treatment_Emissions', 'Anaerobic_Wastewater_Treatment'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Waste Management', 'Waste Management In The Growing Season'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Wood Biomass', 'Woody Biomass'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Nitrous Oxide', 'Nitrous Oxide Emission Factor', 'Nitrous Oxide Emissions', 'Nitrous Oxide Emissions From Fertilizer Application', 'Nitrous Oxide Emissions From Soil'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Ghg Emissions', 'Ghg Emission Reduction', 'Ghg Emission Activities', 'Ghg Emission Factor'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Methane', 'Methane (Ch4)', 'Methane Emissions', 'Methane Emissions From Anaerobic Decomposition In Waste', 'Methane Emissions From Biomass Burning', 'Methane Emissions From Soil', 'Methane Emissions Reduction From Biomass Burning'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Nitrous Oxide', 'Nitrous Oxide Emissions', 'Nitrous Oxide Emissions From Fertilizer Application', 'Nitrous Oxide Emissions From Soil'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Thailand Greenhouse Gas Management Organization (Public Organization) (Tgo)', 'Thailand Greenhouse Gas Management Organization (Tgo) Thailand'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Dioxide', 'Carbon Dioxide Emission Factor', 'Carbon Dioxide Emissions From Urea Fertilization'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Anaerobic Treatment Process', 'Anaerobic Treatment', 'Anaerobic Treatment Process'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas', 'Greenhouse Gas Emission', 'Greenhouse Gas Emission Calculation', 'Greenhouse Gas Emission Calculation Activities', 'Greenhouse Gas Emission Coefficient For Urea', 'Greenhouse Gas Emission Coefficient Of Fuel Type I', 'Greenhouse Gas Emission Factor', 'Greenhouse Gas Emission Factor For Combustion Of Fossil Fuel Type', 'Greenhouse Gas Emission Factor For Electricity Consumption', 'Greenhouse Gas Emission Factor For Electricity Production From Fossil Fuels', 'Greenhouse Gas Emission Factor For Electricity Production From Renewable Energy', 'Greenhouse Gas Emission Model From Rice Cultivation', 'Greenhouse Gas Emission Reduction', 'Greenhouse Gas Emission Reduction Activities', 'Greenhouse Gas Emission Reductions', 'Greenhouse Gas Emissions', 'Greenhouse Gas Emissions Baseline', 'Greenhouse Gas Emissions Calculation', 'Greenhouse Gas Emissions Calculation From Baseline', 'Greenhouse Gas Emissions Calculation From Project Activities'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emission Factors', 'Emission Factors', 'Emission Factor'] due to missing nodes.
# ...
# WARNING:__main__:Skipping merge for group ['Coal Emissions', 'Coal Emissions From Natural Gas Combustion', 'Coal Emissions From Fossil Fuels'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Management Organization', 'Greenhouse Gas Management Organization (Public Organization) (Tgo)', 'Thailand Greenhouse Gas Management Organization (Tgo) Thailand'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Methane', 'Methane (Ch4)', 'Methane Emissions', 'Methane Emissions From Anaerobic Decomposition In Waste', 'Methane Emissions From Biomass Burning', 'Methane Emissions From Soil', 'Methane Emissions Reduction'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emission Factor', 'Greenhouse Gas Emission Factor For Electricity Use', 'Greenhouse Gas Emission Factor For Electricity Production From Fossil Fuels', 'Greenhouse Gas Emission Factor For Electricity Production From Renewable Energy'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Neutral', 'Carbon Neutral Fuel'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Landfill_Biogas', 'Landfill Gas'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Stocks', 'Carbon Stock In Trees', 'Carbon Stocks In Woody Biomass', 'Carbon Storage'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Emission Reduction Activities', 'Emission Reduction Calculation'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Nitrous Oxide Emission Factor', 'Nitrous Oxide Emission Factors'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Dioxide Emissions', 'Carbon Dioxide Emission Reduction From Fossil Fuels', 'Carbon Dioxide Emission Factor'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Electricity Production', 'Electricity Production From Renewable Sources', 'Electricity Production For Supplying To Electricity Consumer', 'Electricity Production Of Power Generation Units'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Waste Management', 'Waste Management Process', 'Waste Management System'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Emissions Calculation', 'Emissions', 'Emissions Calculation From Baseline'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Emission Factor', 'Carbon Emission Factors', 'Carbon Emissions'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Amount Of Electricity Consumed', 'Amount Of Electricity Used In Project Implementation', 'Amount Of Electricity Used In Project Operations In Year Y'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Project Emission Calculation', 'Project Emission', 'Project Emission Calculation'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Methane Emissions', 'Methane Emissions From Biomass Burning', 'Methane Emissions From Soil', 'Methane Emissions From Soil Organic Carbon'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Taxonomy', 'Taxi', 'Taxis'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['2000 Ipcc Good Practice Guidance', 'Ipcc Guidelines 2000'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emission Factor', 'Greenhouse Gas Emission Factor For Electricity Consumption', 'Greenhouse Gas Emission Factor For Electricity Production From Fossil Fuels', 'Greenhouse Gas Emission Factor For Electricity Production From Renewable Energy', 'Greenhouse Gas Emission Factor From Dolomite', 'Greenhouse Gas Emission Factor From Limestone'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Nitrous Oxide Emissions', 'Nitrous Oxide Emissions From Fertilizer Application', 'Nitrous Oxide Emissions From Soil'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Anaerobic Treatment Process', 'Anaerobic Treatment', 'Anaerobic_Treatment', 'Anaerobic Treatment Process', 'Anaerobic Wastewater Treatment', 'Anaerobic Wastewater Treatment System', 'Anaerobic_Wastewater_Treatment'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Nitrous Oxide', 'Nitrous Oxide Emissions', 'Nitrous Oxide Emissions From Fertilizer Application', 'Nitrous Oxide Emissions From Soil', 'Nitrous Oxide Emissions From Soil Nitrogen Application In Baseline Scenario', 'Nitrous Oxide Emissions From Soil Nitrogen Application In Project Implementation', 'Nitrous_Oxide', 'Nitrous_Oxide_Emissions'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Dioxide', 'Carbon Dioxide (Co2)', 'Carbon Dioxide Emissions', 'Carbon Dioxide Emissions From Fertilizer And Lime Usage', 'Carbon Dioxide Emissions From Peat Land In Baseline Scenario'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Climate Change', 'Climate Change Mitigation', 'Climate Change Adaptation'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Baseline Emission Calculation', 'Baseline Emissions Calculation', 'Baseline Emissions', 'Baseline Emissions Calculation'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Emission Factor For Nitrous Oxide', 'Emission Factor For N2O', 'Emission Factor For Nitrous Oxide', 'Emission_Factor', 'Nitrous Oxide Emission Factor', 'Nitrous_Oxide_Emission_Factor'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Biomass Emissions', 'Biomass Emissions From Biomass Burning', 'Biomass Burning'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emissions From Biogas Leakage', 'Greenhouse Gas Emissions From Biogas Flaring', 'Greenhouse Gas Emissions From Biogas Leakage Outside The Project Boundary', 'Greenhouse Gas Emissions From The Use Of Fossil Fuels For Fuel Transport', 'Greenhouse Gas Emissions From The Use Of Fossil Fuels Outside The Project Boundary In Year Y'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Fossil Fuel Consumption', 'Fossil Fuel Consumption Parameter', 'Fossil Fuel Consumption Trends', 'Fossil Fuel Consumption Emissions', 'Fossil Fuel Consumption Of Fossil Fuel Type I In Case Of Project Implementation In Year T'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Dioxide Emissions From Peat Land In Year T', 'Carbon Dioxide Emissions In Project Implementation', 'Carbon Dioxide Emissions From Fossil Fuels', 'Carbon Dioxide Emissions From The Baseline', 'Carbon Dioxide Emissions From The Destruction Of Biogas'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Nitrous Oxide', 'Nitrous Oxide Emissions', 'Nitrous Oxide Emissions From Fertilizer Application', 'Nitrous Oxide Emissions From Soil'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emission Reduction', 'Greenhouse Gas Emission Reductions', 'Greenhouse Gas Emission Reduction Activities', 'Greenhouse Gas Emission Reduction Activities', 'Greenhouse Gas Emission Reduction In Year Y'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emission Factor', 'Greenhouse Gas Emission Factors', 'Emission Factors'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Methane Emissions From Biomass Burning', 'Methane Emissions From Biomass Burning In Year T'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Financing', 'Financing Mechanism', 'Financial Mechanism'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Emissions', 'Emissions Calculation', 'Emissions From Electricity Consumption'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Stocks', 'Carbon Stocks In Woody Biomass', 'Carbon Stocks In Soil Organic Carbon'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Landfill_Biogas', 'Landfill Biogas'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Landfill Gas', 'Landfill Gas Emissions'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Amount Of Electricity Used In Project Implementation', 'Amount Of Electricity Used In Project Operation In Year Y', 'Amount Of Electricity Used In Project Operations In Year Y', 'Amount Of Electricity Used In The Baseline Scenario In Year Y', 'Amount Of Electricity Used'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Methane', 'Methane Emissions', 'Methane Emissions From Soil', 'Methane Emissions From Biomass Burning', 'Methane Emissions From Anaerobic Decomposition In Waste', 'Methane Emissions From Biomass Burning In Project Implementation', 'Methane Emissions From Soil Organic Carbon In Project Implementation', 'Methane Emissions Reduction From Biomass Burning'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Assessment Method 1', 'Assessment Method 2', 'Assessment Method 3', 'Assessment Methods', 'Assessment_Method_1', 'Assessment_Method_2', 'Assessment_Method_3'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Calculation', 'Calculation Methods', 'Calculation Of Greenhouse Gas Emissions', 'Calculation Of Carbon Stocks And Change In Carbon Stocks Of Trees In Forest Project Activities', 'Calculation Of Emission Reduction', 'Calculation Of Emission Reductions', 'Calculation Of Greenhouse Gas Emissions Outside Project Boundaries', 'Calculation_Of_Greenhouse_Gas_Emissions_Outside_The_Project_Boundary'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Anaerobic Treatment Process', 'Anaerobic Treatment', 'Anaerobic Treatment Process', 'Anaerobic Treatment System'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Ghg Emission Factor', 'Ghg Emission Factors', 'Ghg Emissions', 'Ghg Emission Reduction', 'Ghg Emission Reductions'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Nitrous Oxide Emissions', 'Nitrous Oxide Emissions From Soil', 'Nitrous Oxide Emissions From Fertilizer Application', 'Nitrous Oxide Emissions From Volatilization'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emission Factor', 'Greenhouse Gas Emission Factors', 'Greenhouse Gas Emission Reduction', 'Greenhouse Gas Emissions Reduction'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Baseline Emission Calculation', 'Baseline Emissions Calculation', 'Baseline Emissions', 'Baseline Emissions Calculation', 'Baseline Emissions Of Sludge Treatment Systems'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emissions Project', 'Greenhouse Gas Emissions Project_Implementation_Season_S', 'Greenhouse Gas Emissions Project_Implementation_Year_Y', 'Greenhouse Gas Emissions Project_Operation'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Nitrous Oxide', 'Nitrous Oxide Emissions', 'Nitrous Oxide Emissions From Biomass Burning In Baseline Scenario', 'Nitrous Oxide Emissions From Fertilizer Application', 'Nitrous Oxide Emissions From Soil'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Thailand Greenhouse Gas Management Organization', 'Thailand Greenhouse Gas Management Organization (Public Organization)', 'Thailand Greenhouse Gas Management Organization (Public Organization) (Tgo)', 'Thailand Greenhouse Gas Management Organization (Tgo) Thailand'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Baseline Emission Calculation', 'Baseline Emissions Calculation', 'Baseline Emissions', 'Baseline Emission', 'Baseline Emissions Of Sludge Treatment Systems', 'Baseline Emissions Calculation', 'Baseline Ghg Emissions', 'Baseline Greenhouse Gas Emissions'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Dioxide Emissions', 'Carbon Dioxide Emissions Assessment', 'Carbon Dioxide Emissions From Urea Fertilization', 'Carbon Dioxide Emissions From Peat Land In Baseline Scenario', 'Carbon Dioxide Emissions In Baseline Scenario', 'Carbon Dioxide Emissions From Electricity Consumption'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Calculation Of Greenhouse Gas Emissions', 'Calculation Of Greenhouse Gas Emissions From Project Implementation', 'Calculation Of Greenhouse Gas Emissions From The Baseline', 'Calculation Of Greenhouse Gas Emissions Outside Project Boundaries', 'Calculation Of Emission Reductions'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Sequestration', 'Carbon Sequestration Activities', 'Carbon Sequestration Tools', 'Carbon Sequestration Trees', 'Carbon Stock'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Management Organization', 'Greenhouse Gas Management Organization (Public Organization) (Tgo) Thailand', 'Greenhouse Gas Management Organization (Tgo)'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Aerobic Treatment Process', 'Anaerobic Treatment Process', 'Anaerobic Treatment', 'Anaerobic Treatment Process'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emission Factors', 'Greenhouse Gas Emission Reductions'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gas Emissions From Fossil Fuels', 'Greenhouse Gas Emissions From Fossil Fuels Type I For Project Operations In Year Y', 'Greenhouse Gas Emissions From Fossil Fuels Type I In Year Y'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Taxicab', 'Taxi Surveys', 'Taxis', 'Number Of Taxis In Service'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Heat Production', 'Heat Energy Production', 'Heat Energy Generation'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Dioxide Emissions', 'Carbon Dioxide Emissions Assessment', 'Carbon Dioxide Emissions From Liming', 'Carbon Dioxide Emissions From Peat Land In Baseline Scenario', 'Carbon Dioxide Emissions From Urea Fertilization', 'Carbon Dioxide Emissions In Baseline Scenario', 'Carbon Dioxide Emissions In Project Implementation', 'Carbon Dioxide Emissions From Fertilizer And Lime Usage', 'Carbon_Dioxide_Emissions'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Nitrous Oxide Emissions', 'Nitrous Oxide Emissions From Fertilizer Application', 'Nitrous Oxide Emissions From Soil', 'Nitrous Oxide_Emissions'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Anaerobic Treatment Process', 'Anaerobic Treatment', 'Anaerobic Treatment Process', 'Anaerobic Wastewater Treatment', 'Anaerobic Wastewater Treatment System', 'Anaerobic_Treatment'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Project Emissions', 'Project Emissions From Fossil Fuel Consumption', 'Project Emissions From Project Activities', 'Project Emission Calculation', 'Project_Emissions'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Carbon Emissions', 'Carbon Emissions From Burning Fossil Fuels', 'Carbon Emissions From Soil Organic Carbon In Project Implementation', 'Carbon Emissions From Electricity Consumption', 'Carbon Emissions From The Baseline Case'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Emissions Calculation', 'Emissions', 'Emissions From Electricity Consumption', 'Emissions From Project Operations', 'Emissions Calculation From Baseline'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Greenhouse Gases', 'Greenhouse_Gas_Emission', 'Greenhouse_Gas_Emission_Factor', 'Greenhouse_Gas_Emissions_Co2'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Cement Use', 'Cement Emissions'] due to missing nodes.
# WARNING:__main__:Skipping merge for group ['Assessment Method 1', 'Assessment Methods', 'Assessment_Method_1', 'Assessment_Methods'] due to missing nodes.
